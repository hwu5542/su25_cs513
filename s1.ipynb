# %%
import pandas as pd
import numpy as np
from pathlib import Path

ROOT_FOLDER = "NYPL-menus"
# ROOT_FOLDER = "NYPL-menus-cleaned"

MENU = 1
MENU_PAGE = 3
MENU_ITEM = 2
DISH = 0

# %% [markdown]
# # Data Preview Workflow Instructions
#
# ## Accessing Datasets
#
# Each dataset can be accessed from the dataset collection using the following keys:
#
# ```python
# dataset["MENU"]          # Menu data
# dataset["MENU_PAGE"]     # Menu page data
# dataset["MENU_ITEM"]     # Menu item data
# dataset["DISH"]          # Dish data
# ```
#
# ## Preview the Cleaned Dataset
#
# Update the ROOT_FOLDER variable to point to your cleaned data directory:
#
# ```python
# ROOT_FOLDER = "NYPL-menus-cleaned"  # Path to cleaned data
# ```

# %%
dataset = []

for filename in sorted(Path(ROOT_FOLDER).iterdir()):
    if filename.name.endswith(".csv"):
        dataset.append(pd.read_csv(filename, na_values=[""]))

# %%
# dataset[MENU].head()
# dataset[MENU_PAGE].head()
# dataset[MENU_ITEM].head()
dataset[DISH].head()
# Out:
#    id                        name  description  menus_appeared  \
# 0   1  Consomme printaniere royal          NaN               8
# 1   2               Chicken gumbo          NaN             111
# 2   3         Tomato aux croutons          NaN              13
# 3   4             Onion au gratin          NaN              41
# 4   5                 St. Emilion          NaN              66
#
#    times_appeared  first_appeared  last_appeared  lowest_price  highest_price
# 0               8            1897           1927          0.20            0.4
# 1             117            1895           1960          0.10            0.8
# 2              13            1893           1917          0.25            0.4
# 3              41            1900           1971          0.25            1.0
# 4              68            1881           1981          0.00           18.0

# %%
dataset[MENU].info()
# dataset[MENU_PAGE].info()
# dataset[MENU_ITEM].info()
# dataset[DISH].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17545 entries, 0 to 17544
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17545 non-null  int64
#  1   name                  3197 non-null   object
#  2   sponsor               15984 non-null  object
#  3   event                 8154 non-null   object
#  4   venue                 8119 non-null   object
#  5   place                 8123 non-null   object
#  6   physical_description  14763 non-null  object
#  7   occasion              3791 non-null   object
#  8   notes                 10613 non-null  object
#  9   call_number           15983 non-null  object
#  10  keywords              0 non-null      float64
#  11  language              0 non-null      float64
#  12  date                  16959 non-null  object
#  13  location              17545 non-null  object
#  14  location_type         0 non-null      float64
#  15  currency              6456 non-null   object
#  16  currency_symbol       6456 non-null   object
#  17  status                17545 non-null  object
#  18  page_count            17545 non-null  int64
#  19  dish_count            17545 non-null  int64
# dtypes: float64(3), int64(3), object(14)
# memory usage: 2.7+ MB

# %%
# print(dataset[MENU].isna().sum())
# print(dataset[MENU_PAGE].isna().sum())
print(dataset[MENU_ITEM].isna().sum())
# print(dataset[DISH].isna().sum())
# Out:
# id                    0
# menu_page_id          0
# price            445916
# high_price      1240821
# dish_id             241
# created_at            0
# updated_at            0
# xpos                  0
# ypos                  0
# dtype: int64

# %%
dataset[MENU].describe(include="all")
# dataset[MENU_PAGE].describe(include="all")
# dataset[MENU_ITEM].describe(include="all")
# dataset[DISH].describe(include="all")
# Out:
#                   id             name          sponsor   event       venue  \
# count   17545.000000             3197            15984    8154        8119
# unique           NaN              797             6370    1770         233
# top              NaN  Waldorf Astoria  Waldorf Astoria  DINNER  COMMERCIAL
# freq             NaN              475              691    1827        4704
# mean    25325.953377              NaN              NaN     NaN         NaN
# std      6431.552203              NaN              NaN     NaN         NaN
# min     12463.000000              NaN              NaN     NaN         NaN
# 25%     20742.000000              NaN              NaN     NaN         NaN
# 50%     26165.000000              NaN              NaN     NaN         NaN
# 75%     30707.000000              NaN              NaN     NaN         NaN
# max     35526.000000              NaN              NaN     NaN         NaN
#
#            place            physical_description occasion  \
# count       8123                           14763     3791
# unique      3714                            6268      423
# top     EN ROUTE  BROADSHEET; ILLUS; 6.5 X 7.75;   DAILY;
# freq         293                             127      828
# mean         NaN                             NaN      NaN
# std          NaN                             NaN      NaN
# min          NaN                             NaN      NaN
# 25%          NaN                             NaN      NaN
# 50%          NaN                             NaN      NaN
# 75%          NaN                             NaN      NaN
# max          NaN                             NaN      NaN
#
#                             notes call_number  keywords  language        date  \
# count                       10613       15983       0.0       0.0       16959
# unique                       6969       15936       NaN       NaN        6599
# top     Dieter Zander Collection.    1899-806       NaN       NaN  1915-01-01
# freq                          210           3       NaN       NaN         263
# mean                          NaN         NaN       NaN       NaN         NaN
# std                           NaN         NaN       NaN       NaN         NaN
# min                           NaN         NaN       NaN       NaN         NaN
# 25%                           NaN         NaN       NaN       NaN         NaN
# 50%                           NaN         NaN       NaN       NaN         NaN
# 75%                           NaN         NaN       NaN       NaN         NaN
# max                           NaN         NaN       NaN       NaN         NaN
#
#                location  location_type currency currency_symbol    status  \
# count             17545            0.0     6456            6456     17545
# unique             6283            NaN       42              34         2
# top     Waldorf Astoria            NaN  Dollars               $  complete
# freq                703            NaN     5549            5579     17371
# mean                NaN            NaN      NaN             NaN       NaN
# std                 NaN            NaN      NaN             NaN       NaN
# min                 NaN            NaN      NaN             NaN       NaN
# 25%                 NaN            NaN      NaN             NaN       NaN
# 50%                 NaN            NaN      NaN             NaN       NaN
# 75%                 NaN            NaN      NaN             NaN       NaN
# max                 NaN            NaN      NaN             NaN       NaN
#
#           page_count    dish_count
# count   17545.000000  17545.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        3.484412     75.617213
# std         3.295643     98.435862
# min         1.000000      0.000000
# 25%         2.000000     20.000000
# 50%         2.000000     35.000000
# 75%         4.000000     93.000000
# max        74.000000   4053.000000

# %%
dishJoinMenuItem = pd.merge(
    dataset[DISH],
    dataset[MENU_ITEM],
    how="left",
    left_on="id",
    right_on="dish_id",
)

dishJoinMenuItem.head()
# Out:
#    id_x                        name  description  menus_appeared  \
# 0     1  Consomme printaniere royal          NaN               8
# 1     1  Consomme printaniere royal          NaN               8
# 2     1  Consomme printaniere royal          NaN               8
# 3     1  Consomme printaniere royal          NaN               8
# 4     1  Consomme printaniere royal          NaN               8
#
#    times_appeared  first_appeared  last_appeared  lowest_price  highest_price  \
# 0               8            1897           1927           0.2            0.4
# 1               8            1897           1927           0.2            0.4
# 2               8            1897           1927           0.2            0.4
# 3               8            1897           1927           0.2            0.4
# 4               8            1897           1927           0.2            0.4
#
#        id_y  menu_page_id  price  high_price  dish_id  \
# 0       1.0        1389.0    0.4         NaN      1.0
# 1   73003.0         248.0    NaN         NaN      1.0
# 2  140158.0        5129.0    0.2         NaN      1.0
# 3  168416.0        1677.0    0.4         NaN      1.0
# 4  244132.0       24766.0    NaN         NaN      1.0
#
#                 created_at               updated_at      xpos      ypos
# 0  2011-03-28 15:00:44 UTC  2011-04-19 04:33:15 UTC  0.111429  0.254735
# 1  2011-04-26 20:51:20 UTC  2011-04-26 20:51:20 UTC  0.344286  0.498271
# 2  2011-05-01 14:33:47 UTC  2012-12-23 21:55:44 UTC  0.264286  0.423484
# 3  2011-05-04 20:00:45 UTC  2011-05-04 20:00:45 UTC  0.100000  0.254735
# 4  2011-05-17 23:09:51 UTC  2011-05-17 23:09:51 UTC  0.380000  0.333310
